# %% [markdown]
# **GIT CLONE**

# %% [markdown]
# ![3_Ingestao_Arquivos.png](data:image/png;base64,...)

# %% [markdown]
# **INGESTÃO HDFS**

# %% [markdown]
# ![4_arquivo_hdfs.png](data:image/png;base64,...)

# %% [markdown]
# **HIVE**

# %% [markdown]
# ![5_hive1.png](data:image/png;base64,...)

# %% [markdown]
# **CRIAÇÃO DO DATABASE CAPGEMINI**

# %% [markdown]
# ![6_hive_database.png](data:image/png;base64,...)

# %% [markdown]
# **CRIAÇÃO DA TABELA HIVE**

# %% [markdown]
# ![6_hive_tabela.png](data:image/png;base64,...)

# %% [markdown]
# **TABELA quadro_medalhas EM DETALHES**

# %% [markdown]
# ![8_hive_tabela_desc.png](data:image/png;base64,...)

# %% [markdown]
# **CONSULTA ANTES DA INGESTÃO DE DADOS**

# %% [markdown]
# ![9_hive_tabela_insert1.png](data:image/png;base64,...)

# %% [markdown]
# **CONSULTA NA TABELA HIVE APÓS INGESTÃOI DE DADOS (ORIGEM HDFS)**

# %% [markdown]
# ![10_hive_tabela_insert2.png](data:image/png;base64,...)

# %% [markdown]
# **CÉZAR AUGUSTO MEIRA CARMO - cezaraugustomeiracarmo@gmail.com**
